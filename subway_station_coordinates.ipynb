# %% [markdown]
# # Process the subway station entrance/exit coordinate data

# %%
from datetime import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

import geopandas as gpd
import pandas as pd
import pygmt

import turnstile as ts

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv("dat/NYC_Transit_Subway_Entrance_And_Exit_Data.csv")

# %%
df
# Out:
#      Division      Line          Station Name  Station Latitude  \
# 0         IND  Rockaway  Far Rockaway-Mott Av         40.603995
# 1         IND  Rockaway         Beach 25th St         40.600066
# 2         IND  Rockaway         Beach 25th St         40.600066
# 3         IND  Rockaway         Beach 25th St         40.600066
# 4         IND  Rockaway         Beach 36th St         40.595398
# ...       ...       ...                   ...               ...
# 1863      BMT  4 Avenue               95th St         40.616622
# 1864      BMT  4 Avenue               95th St         40.616622
# 1865      BMT  4 Avenue               95th St         40.616622
# 1866      BMT  4 Avenue               95th St         40.616622
# 1867      BMT  4 Avenue               95th St         40.616622
#
#       Station Longitude Route1 Route2 Route3 Route4 Route5  ...  \
# 0            -73.755405      A    NaN    NaN    NaN    NaN  ...
# 1            -73.761353      A    NaN    NaN    NaN    NaN  ...
# ...

# %%
for x in df['Station Name'].unique():
    if "125" in x:
        print("'{:s}'".format(x))
# Out:
# '125th St'

# %%
sel = np.logical_and(
    df['Station Name'] == '125th St',
    df['Line'] == '8 Avenue',
)

# %%
df[sel]
# Out:
#     Division      Line Station Name  Station Latitude  Station Longitude  \
# 863      IND  8 Avenue     125th St         40.811109         -73.952343
# 864      IND  8 Avenue     125th St         40.811109         -73.952343
# 865      IND  8 Avenue     125th St         40.811109         -73.952343
# 866      IND  8 Avenue     125th St         40.811109         -73.952343
# 867      IND  8 Avenue     125th St         40.811109         -73.952343
# 868      IND  8 Avenue     125th St         40.811109         -73.952343
#
#     Route1 Route2 Route3 Route4 Route5  ... Free Crossover  \
# 863      A      B      C      D    NaN  ...           True
# 864      A      B      C      D    NaN  ...           True
# 865      A      B      C      D    NaN  ...           True
# 866      A      B      C      D    NaN  ...           True
# 867      A      B      C      D    NaN  ...           True
# 868      A      B      C      D    NaN  ...           True
#
# ...

# %%
df[df['Station Name'] == '125th St']
# Out:
#     Division              Line Station Name  Station Latitude  \
# 683      IRT         Lexington     125th St         40.804138
# 684      IRT         Lexington     125th St         40.804138
# 685      IRT         Lexington     125th St         40.804138
# 686      IRT         Lexington     125th St         40.804138
# 687      IRT         Lexington     125th St         40.804138
# 772      IRT             Lenox     125th St         40.807754
# 773      IRT             Lenox     125th St         40.807754
# 774      IRT             Lenox     125th St         40.807754
# 775      IRT             Lenox     125th St         40.807754
# 863      IND          8 Avenue     125th St         40.811109
# 864      IND          8 Avenue     125th St         40.811109
# 865      IND          8 Avenue     125th St         40.811109
# 866      IND          8 Avenue     125th St         40.811109
# 867      IND          8 Avenue     125th St         40.811109
# ...
